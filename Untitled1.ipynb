# %%
import pandas as pd

# %%
store = pd.read_csv("f500.csv")

# %%
store
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
store["country"].value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
store["country"].loc[:5]
# Out:
# 0        USA
# 1      China
# 2      China
# 3      China
# 4      Japan
# 5    Germany
# Name: country, dtype: object

# %%
store["country"].iloc[:5]
# Out:
# 0      USA
# 1    China
# 2    China
# 3    China
# 4    Japan
# Name: country, dtype: object

# %%
cat = store["country"] == "USA"

# %%
cat1 = store[cat]

# %%
cat1
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 0               Walmart     1    485873             0.8  13643.0  198825
# 7    Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                 Apple     9    215639            -7.7  45687.0  321686
# 9           Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10             McKesson    11    198533             3.1   5070.0   60969
# ..                  ...   ...       ...             ...      ...     ...
# 480        U.S. Bancorp   481     22744             5.8   5888.0  445964
# 482               Aflac   483     22559             8.1   2659.0  129819
# 488      Sears Holdings   489     22138           -12.0  -2221.0    9362
# 491      Dollar General   492     21987             7.9   1251.1   11672
# 499          AutoNation   500     21609             3.6    430.5   10060
#
#      profit_change                  ceo  \
# 0             -7.2  C. Douglas McMillon
# ...

# %%
cat1.sort_values("revenues", ascending = True)
# Out:
#                 company  rank  revenues  revenue_change  profits  assets  \
# 499          AutoNation   500     21609             3.6    430.5   10060
# 491      Dollar General   492     21987             7.9   1251.1   11672
# 488      Sears Holdings   489     22138           -12.0  -2221.0    9362
# 482               Aflac   483     22559             8.1   2659.0  129819
# 480        U.S. Bancorp   481     22744             5.8   5888.0  445964
# ..                  ...   ...       ...             ...      ...     ...
# 10             McKesson    11    198533             3.1   5070.0   60969
# 9           Exxon Mobil    10    205004           -16.7   7840.0  330314
# 8                 Apple     9    215639            -7.7  45687.0  321686
# 7    Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 0               Walmart     1    485873             0.8  13643.0  198825
#
#      profit_change                  ceo  \
# 499           -2.7   Michael J. Jackson
# ...

# %%
cat1.set_index("company")
# Out:
#                     rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                1    485873             0.8  13643.0  198825
# Berkshire Hathaway     8    223604             6.1  24074.0  620854
# Apple                  9    215639            -7.7  45687.0  321686
# Exxon Mobil           10    205004           -16.7   7840.0  330314
# McKesson              11    198533             3.1   5070.0   60969
# ...                  ...       ...             ...      ...     ...
# U.S. Bancorp         481     22744             5.8   5888.0  445964
# Aflac                483     22559             8.1   2659.0  129819
# Sears Holdings       489     22138           -12.0  -2221.0    9362
# Dollar General       492     21987             7.9   1251.1   11672
# AutoNation           500     21609             3.6    430.5   10060
#
#                     profit_change                  ceo  \
# company
# Walmart                      -7.2  C. Douglas McMillon
# ...

# %%
store.sort_values("rank", ascending = True)
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
jap = store[store["country"] == "Japan"]

# %%
jap
# Out:
#                              company  rank  revenues  revenue_change  profits  \
# 4                       Toyota Motor     5    254694             7.7  16899.3
# 28                       Honda Motor    29    129198             6.2   5690.3
# 32               Japan Post Holdings    33    122990             3.6   -267.4
# 43                      Nissan Motor    44    108164             6.5   6123.4
# 49      Nippon Telegraph & Telephone    50    105128             9.4   7384.4
# 70                           Hitachi    71     84558             1.2   2134.3
# 71                    SoftBank Group    72     82892             8.4  13163.4
# 86                              AEON    87     75772            11.8    103.9
# 104                             Sony   105     70170             3.9    676.4
# 109                        Panasonic   110     67775             6.7   1378.4
# 110            Nippon Life Insurance   111     67388             0.4   2786.9
# ...

# %%
top1 = jap["sector"].value_counts()[:5]

# %%
top2 = jap["industry"].value_counts()[:5]

# %%
top1.plot.pie()
# Out:
# <AxesSubplot:ylabel='sector'>

# %%
top2.plot.pie()
# Out:
# <AxesSubplot:ylabel='industry'>

# %%
top1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
top2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
sec = jap[jap["sector"] =="Telecommunications"]

# %%
sec
# Out:
#                           company  rank  revenues  revenue_change  profits  \
# 49   Nippon Telegraph & Telephone    50    105128             9.4   7384.4
# 71                 SoftBank Group    72     82892             8.4  13163.4
# 218                          KDDI   219     43822            17.8   5045.1
#
#      assets  profit_change             ceo            industry  \
# 49   190740           20.2    Hiroo Unoura  Telecommunications
# 71   221113          233.3   Masayoshi Son  Telecommunications
# 218   56223           22.5  Takashi Tanaka  Telecommunications
#
#                  sector  previous_rank country   hq_location  \
# 49   Telecommunications             60   Japan  Tokyo, Japan
# 71   Telecommunications             92   Japan  Tokyo, Japan
# 218  Telecommunications            271   Japan  Tokyo, Japan
#
#                     website  years_on_global_500_list  employees  \
# 49     http://www.ntt.co.jp                        23     274844
# ...

# %%
secrev = sec[sec["revenue_change"] >=10]

# %%
secrev
# Out:
#     company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 218    KDDI   219     43822            17.8   5045.1   56223           22.5
#
#                 ceo            industry              sector  previous_rank  \
# 218  Takashi Tanaka  Telecommunications  Telecommunications            271
#
#     country   hq_location              website  years_on_global_500_list  \
# 218   Japan  Tokyo, Japan  http://www.kddi.com                        20
#
#      employees  total_stockholder_equity
# 218      35032                     31904
