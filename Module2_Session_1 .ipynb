# %%
 # meta characters are used for patterens

# %%
date = "30-March-2020"

# %%
import datetime as dt

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%2015.16.58.jpg](attachment:WhatsApp%20Image%202023-07-08%20at%2015.16.58.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-08%20at%2015.16.58.jpg](attachment:WhatsApp%20Image%202023-07-08%20at%2015.16.58.jpg)

# %%
date = "30-March-2020"
pattern = "%d-%B-%Y"

# %%
date = dt.datetime.strptime(date,pattern)

# %%
date
# Out:
# datetime.datetime(2020, 3, 30, 0, 0)

# %%
print(date)
# Out:
# 2020-03-30 00:00:00

# %%
date.day
# Out:
# 30

# %%
date.month
# Out:
# 3

# %%
date.year
# Out:
# 2020

# %%
from csv import reader
dataset = list(reader(open("potus_visitors_2015.csv")))

# %%
data = dataset[1:]

# %%
data
# Out:
# [['Joshua T. Blanton',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
#   'JointService Military Honor Guard'],
#  ['Jack T. Gutting',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
#   'JointService Military Honor Guard'],
#  ['Bradley T. Guiles',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
#   'JointService Military Honor Guard'],
#  ['Loryn F. Grieb',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
#   'JointService Military Honor Guard'],
#  ['Travis D. Gordon',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
#   'JointService Military Honor Guard'],
#  ['Taylor D. Gibbs',
#   '2014-12-18T00:00:00',
#   '1/6/2015 9:30',
#   '1/6/2015 23:59',
#   '',
#   'potus',
#   'west wing',
# ...

# %%
pattern = "%m/%d/%Y %H:%M"

# %%
for i in data:
    i[2] = dt.datetime.strptime(i[2],pattern)
    i[3] = dt.datetime.strptime(i[3],pattern)
    print(i[2], i[3])
# Out:
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# 2015-01-06 09:30:00 2015-01-06 23:59:00
# ...

# %%
date
# Out:
# datetime.datetime(2020, 3, 30, 0, 0)

# %%
date
# Out:
# datetime.datetime(2020, 3, 30, 0, 0)

# %%
dt.datetime.strftime(date, "Meeting Date: %d/%B/%Y at 3 PM")
# Out:
# 'Meeting Date: 30/March/2020 at 3 PM'

# %%
visiting = {}
for i in data:
    month = i[2].month
    if month not in visiting:
        visiting[month] = 1
    else:
        visiting[month] = +=1
# Out:
#   File "C:\Users\Bilal\AppData\Local\Temp\ipykernel_17112\2688207948.py", line 7
#     visiting[month] = +=1
#                       ^
# SyntaxError: invalid syntax

# %%
visiting = {}
for i in data:
    month = dt.datetime.strftime(i[2], "%B")
    # print(month)
    if month not in visiting:
        visiting[month] = 1
    else:
        visiting[month] = +=1
# Out:
#   File "C:\Users\Bilal\AppData\Local\Temp\ipykernel_17112\2211881348.py", line 8
#     visiting[month] = +=1
#                       ^
# SyntaxError: invalid syntax
