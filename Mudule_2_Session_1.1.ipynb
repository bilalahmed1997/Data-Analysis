# %%
import pandas as pd

# %%
f500 = pd.read_csv("f500.csv")

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
f500.head()  #shift tab tells description
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
f500.head(10)
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
# 6         Royal Dutch Shell     7    240033           -11.8   4575.0  411275
# 7        Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                     Apple     9    215639            -7.7  45687.0  321686
# 9               Exxon Mobil    10    205004           -16.7   7840.0  330314
#
#    profit_change                  ceo  \
# 0           -7.2  C. Douglas McMillon
# 1           -6.2              Kou Wei
# ...

# %%
# f500.head? also shows description

# %%
f500.tail(7)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 493     35.6   12161          -25.1           Xu Xiaoxi
# 494    251.8   31957           49.9       Shang Jiqiang
# 495    329.0   92890          -79.3   Yitzhak Peterburg
# 496    743.9  100609          -45.6            Wan Feng
# 497    406.4   11630           20.4      David T. Potts
# ...

# %%
f500.shape # shows nmbr of rows and columns
# Out:
# (500, 17)

# %%
f500.dtypes # in pandas string is called object
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
f500["company"]
# Out:
# 0                             Walmart
# 1                          State Grid
# 2                       Sinopec Group
# 3            China National Petroleum
# 4                        Toyota Motor
#                     ...
# 495    Teva Pharmaceutical Industries
# 496          New China Life Insurance
# 497         Wm. Morrison Supermarkets
# 498                               TUI
# 499                        AutoNation
# Name: company, Length: 500, dtype: object

# %%
data = f500[["company", "ceo","rank"]]

# %%
data
# Out:
#                             company                  ceo  rank
# 0                           Walmart  C. Douglas McMillon     1
# 1                        State Grid              Kou Wei     2
# 2                     Sinopec Group            Wang Yupu     3
# 3          China National Petroleum        Zhang Jianhua     4
# 4                      Toyota Motor          Akio Toyoda     5
# ..                              ...                  ...   ...
# 495  Teva Pharmaceutical Industries    Yitzhak Peterburg   496
# 496        New China Life Insurance             Wan Feng   497
# 497       Wm. Morrison Supermarkets       David T. Potts   498
# 498                             TUI    Friedrich Joussen   499
# 499                      AutoNation   Michael J. Jackson   500
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Label Indexing and Integer Indexing
#
# * label indexing is front end indexing and can be integer, float and string
# * Integer indexing is backend indexing and can not be seen

# %%
data.drop(2)
# Out:
#                             company                  ceo  rank
# 0                           Walmart  C. Douglas McMillon     1
# 1                        State Grid              Kou Wei     2
# 3          China National Petroleum        Zhang Jianhua     4
# 4                      Toyota Motor          Akio Toyoda     5
# 5                        Volkswagen      Matthias Muller     6
# ..                              ...                  ...   ...
# 495  Teva Pharmaceutical Industries    Yitzhak Peterburg   496
# 496        New China Life Insurance             Wan Feng   497
# 497       Wm. Morrison Supermarkets       David T. Potts   498
# 498                             TUI    Friedrich Joussen   499
# 499                      AutoNation   Michael J. Jackson   500
#
# [499 rows x 3 columns]

# %%
f500.iloc[0]
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f500.iloc[[0,5]]
# Out:
#       company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0     Walmart     1    485873             0.8  13643.0  198825           -7.2
# 5  Volkswagen     6    240264             1.5   5937.3  432116            NaN
#
#                    ceo                  industry                  sector  \
# 0  C. Douglas McMillon     General Merchandisers               Retailing
# 5      Matthias Muller  Motor Vehicles and Parts  Motor Vehicles & Parts
#
#    previous_rank  country         hq_location                    website  \
# 0              1      USA     Bentonville, AR     http://www.walmart.com
# 5              7  Germany  Wolfsburg, Germany  http://www.volkswagen.com
#
#    years_on_global_500_list  employees  total_stockholder_equity
# 0                        23    2300000                     77798
# 5                        23     626715                     97753

# %%
f500.iloc[0:6]
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
# 5                Volkswagen     6    240264             1.5   5937.3  432116
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
# ...

# %%
f500.iloc[[0,6],[0,1,7]]
# Out:
#              company  rank                  ceo
# 0            Walmart     1  C. Douglas McMillon
# 6  Royal Dutch Shell     7      Ben van Beurden

# %%
f500.loc[0]
# Out:
# company                                    Walmart
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: 0, dtype: object

# %%
f500.loc[:6, ["company","rank","revenues","ceo"]] # row from o to 6 with columns company,rank,revenues
# Out:
#                         company  rank  revenues                  ceo
# 0                       Walmart     1    485873  C. Douglas McMillon
# 3      China National Petroleum     4    262573        Zhang Jianhua
# 118            China Post Group   119     65605            Li Guohua
# 1                    State Grid     2    315199              Kou Wei
# 26   Hon Hai Precision Industry    27    135129            Terry Gou
# ..                          ...   ...       ...                  ...
# 300                       Volvo   301     35269     Martin Lundstedt
# 378                     L’Oreal   379     28572       Jean-Paul Agon
# 337      China Evergrande Group   338     31828            Hui Kayan
# 291             Intesa Sanpaolo   292     36225        Carlo Messina
# 6             Royal Dutch Shell     7    240033      Ben van Beurden
#
# [261 rows x 4 columns]

# %% [markdown]
# * loc is used as a destinaton point
# * iloc is the normal method of indexing

# %%
f500 = f500.sort_values("employees") # sort w.r.t employees

# %%
f500
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 294              Rajesh Exports   295     36114            43.1    185.8
# 204                 Noble Group   205     46528           -30.3      8.7
# 485                   GS Caltex   486     22207           -11.4   1221.1
# 53              Trafigura Group    54     98098             0.9    750.8
# 401         World Fuel Services   402     27016           -11.1    126.5
# ..                          ...   ...       ...             ...      ...
# 26   Hon Hai Precision Industry    27    135129            -4.3   4608.8
# 1                    State Grid     2    315199            -4.4   9571.3
# 118            China Post Group   119     65605            -5.8   4980.3
# 3      China National Petroleum     4    262573           -12.3   1867.5
# 0                       Walmart     1    485873             0.8  13643.0
#
#       assets  profit_change                  ceo  \
# ...

# %%
f500 = f500.sort_values("employees",ascending = True) #sort ascendingly if True while False in descending order

# %%
f500
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 294              Rajesh Exports   295     36114            43.1    185.8
# 204                 Noble Group   205     46528           -30.3      8.7
# 485                   GS Caltex   486     22207           -11.4   1221.1
# 53              Trafigura Group    54     98098             0.9    750.8
# 401         World Fuel Services   402     27016           -11.1    126.5
# ..                          ...   ...       ...             ...      ...
# 26   Hon Hai Precision Industry    27    135129            -4.3   4608.8
# 1                    State Grid     2    315199            -4.4   9571.3
# 118            China Post Group   119     65605            -5.8   4980.3
# 3      China National Petroleum     4    262573           -12.3   1867.5
# 0                       Walmart     1    485873             0.8  13643.0
#
#       assets  profit_change                  ceo  \
# ...

# %%
f500.loc[[294,53]]
# Out:
#              company  rank  revenues  revenue_change  profits  assets  \
# 294   Rajesh Exports   295     36114            43.1    185.8    3717
# 53   Trafigura Group    54     98098             0.9    750.8   41230
#
#      profit_change              ceo industry       sector  previous_rank  \
# 294           13.8  Rajesh J. Mehta  Trading  Wholesalers            423
# 53           -39.3      Jeremy Weir  Trading  Wholesalers             59
#
#        country       hq_location                     website  \
# 294      India  Bengaluru, India  http://www.rajeshindia.com
# 53   Singapore         Singapore    http://www.trafigura.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 294                         2        328                       868
# 53                          3       4107                      5548

# %%
f500.loc[[294,53]]
# Out:
#              company  rank  revenues  revenue_change  profits  assets  \
# 294   Rajesh Exports   295     36114            43.1    185.8    3717
# 53   Trafigura Group    54     98098             0.9    750.8   41230
#
#      profit_change              ceo industry       sector  previous_rank  \
# 294           13.8  Rajesh J. Mehta  Trading  Wholesalers            423
# 53           -39.3      Jeremy Weir  Trading  Wholesalers             59
#
#        country       hq_location                     website  \
# 294      India  Bengaluru, India  http://www.rajeshindia.com
# 53   Singapore         Singapore    http://www.trafigura.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 294                         2        328                       868
# 53                          3       4107                      5548

# %%
f500.iloc[:5]
# Out:
#                  company  rank  revenues  revenue_change  profits  assets  \
# 294       Rajesh Exports   295     36114            43.1    185.8    3717
# 204          Noble Group   205     46528           -30.3      8.7   12285
# 485            GS Caltex   486     22207           -11.4   1221.1   15969
# 53       Trafigura Group    54     98098             0.9    750.8   41230
# 401  World Fuel Services   402     27016           -11.1    126.5    5413
#
#      profit_change                 ceo            industry       sector  \
# 294           13.8     Rajesh J. Mehta             Trading  Wholesalers
# 204            NaN  William J. Randall             Trading  Wholesalers
# 485           42.1         Jin-Soo Huh  Petroleum Refining       Energy
# 53           -39.3         Jeremy Weir             Trading  Wholesalers
# 401          -27.5   Michael J. Kasbar              Energy       Energy
#
#      previous_rank      country         hq_location  \
# ...

# %%
f500 = f500.sort_values("employees",ascending = False) #sort ascendingly if True while False in descending order

# %%
f500
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 0                       Walmart     1    485873             0.8  13643.0
# 3      China National Petroleum     4    262573           -12.3   1867.5
# 118            China Post Group   119     65605            -5.8   4980.3
# 1                    State Grid     2    315199            -4.4   9571.3
# 26   Hon Hai Precision Industry    27    135129            -4.3   4608.8
# ..                          ...   ...       ...             ...      ...
# 401         World Fuel Services   402     27016           -11.1    126.5
# 53              Trafigura Group    54     98098             0.9    750.8
# 485                   GS Caltex   486     22207           -11.4   1221.1
# 204                 Noble Group   205     46528           -30.3      8.7
# 294              Rajesh Exports   295     36114            43.1    185.8
#
#       assets  profit_change                  ceo  \
# ...
